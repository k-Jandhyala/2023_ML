# %% [markdown]
# **Copyright: © NexStream Technical Education, LLC**.
# All rights reserved

# %%
#PCA from Numpy functions - Assignment 1

#Import numpy, matplotlib, seaborn lib functions
from numpy import array
from numpy import mean
from numpy import cov
from numpy import sum
from numpy import var
from numpy import matmul
from numpy import arange
from numpy import round
from numpy import zeros
from numpy.linalg import eig
import matplotlib.pyplot as plt
import seaborn as sns


# Calculate the mean of each column
def data_mean(data_in):
  return data_in.mean(axis=1)

# Shift data to origin subtracting column means from columns
def data_center(data_in, data_mean):
    centerd_data = zeros(data_in.shape)
    for row in range(len(data_in)):
      col_mean = data_mean[row]
      for value in range(len(data_in[row, :])):
        centerd_data[row][value] = data_in[row][value] - col_mean
    return centerd_data.T

# Calculate covariance matrix of the shifted matrix
def data_cov(data_in):
  return cov(data_in.T)

# Perform Eigen decomposition of covariance matrix
def data_eig(data_in):
  return eig(data_in.T)

# Project data onto new axis
def data_proj(data_in, eigenvectors):
  data_in = data_in
  eigenvectors = eigenvectors
  projected_data = matmul(data_in, eigenvectors)
  return projected_data.T

#Calculate variance ratios
def variance_ratio(eigenvalues):
  return eigenvalues/sum(eigenvalues)


#Run the doctest module.  DO NOT modify any code below this line!
import doctest

data_a = array([[43, 26, 28, 29, 42, 39],
              [8.5, 5.0, 6.1, 4.6, 7.2, 7.4]])
mean_a = data_mean(data_a)
center_a = data_center(data_a, mean_a)
covariance_a = data_cov(center_a)
eigenvalues_a, eigenvectors_a = data_eig(covariance_a)
projection_a = data_proj(center_a, eigenvectors_a)
var_ratio_a = variance_ratio(eigenvalues_a)

data_b = array([[43, 26, 28, 29, 42, 39],
                [8.5, 5.0, 6.1, 4.6, 7.2, 7.4],
                [170, 104, 121, 130, 159, 132],
                [5.0, 5.9, 5.5, 5.8, 4.7, 5.7]])
mean_b = data_mean(data_b)
center_b = data_center(data_b, mean_b)
covariance_b = data_cov(center_b)
eigenvalues_b, eigenvectors_b = data_eig(covariance_b)
projection_b = data_proj(center_b, eigenvectors_b)
var_ratio_b = variance_ratio(eigenvalues_b)

"""
  >>> print(round(mean_a, 4))
  [34.5     6.4667]
  >>> print(round(center_a, 4))
  [[ 8.5     2.0333]
   [-8.5    -1.4667]
   [-6.5    -0.3667]
   [-5.5    -1.8667]
   [ 7.5     0.7333]
   [ 4.5     0.9333]]
  >>> print(round(covariance_a, 4))
  [[58.7    10.42  ]
   [10.42    2.2627]]
  >>> print(round(eigenvalues_a, 4))
  [60.5624  0.4003]
  >>> print(round(eigenvectors_a, 4))
  [[ 0.9844 -0.1759]
   [ 0.1759  0.9844]]
  >>> print(round(projection_a, 4))
  [[ 8.7252 -8.6255 -6.4631 -5.7426  7.512   4.594 ]
   [ 0.5061  0.0517  0.7827 -0.8699 -0.5977  0.127 ]]
  >>> print(round(var_ratio_a, 4))
  [0.9934 0.0066]

  >>> print(round(mean_b, 4))
  [ 34.5      6.4667 136.       5.4333]
  >>> print(round(center_b, 4))
  [[  8.5      2.0333  34.      -0.4333]
   [ -8.5     -1.4667 -32.       0.4667]
   [ -6.5     -0.3667 -15.       0.0667]
   [ -5.5     -1.8667  -6.       0.3667]
   [  7.5      0.7333  23.      -0.7333]
   [  4.5      0.9333  -4.       0.2667]]
  >>> print(round(covariance_b, 4))
  [[ 5.8700e+01  1.0420e+01  1.6920e+02 -2.8800e+00]
   [ 1.0420e+01  2.2627e+00  2.9180e+01 -5.1270e-01]
   [ 1.6920e+02  2.9180e+01  5.9720e+02 -1.0160e+01]
   [-2.8800e+00 -5.1270e-01 -1.0160e+01  2.3070e-01]]
  >>> print(round(eigenvalues_b, 4))
  [6.476053e+02 1.034020e+01 3.908000e-01 5.710000e-02]
  >>> print(round(eigenvectors_b, 4))
  [[-0.2766 -0.9392 -0.2031 -0.0091]
   [-0.0479 -0.1978  0.978   0.0459]
   [-0.9596  0.2806  0.009   0.0173]
   [ 0.0163 -0.0044 -0.047   0.9988]]
  >>> print(round(projection_b, 4))
  [[-3.50837e+01  3.31378e+01  1.62114e+01  7.37470e+00 -2.41936e+01
     2.55330e+00]
   [ 1.15500e+00 -7.06200e-01  1.96890e+00  3.85010e+00 -7.33300e-01
    -5.53450e+00]
   [ 5.87300e-01 -1.68000e-02  8.24000e-01 -7.79500e-01 -5.65400e-01
    -4.95000e-02]
   [ 1.72400e-01 -7.84000e-02 -1.51000e-01  2.26700e-01 -3.68500e-01
     1.98800e-01]]
  >>> print(round(var_ratio_b, 4))
  [9.836e-01 1.570e-02 6.000e-04 1.000e-04]

"""

doctest.testmod(verbose=False)
# Out:
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.9/doctest.py", line 1485, in run
#     sys.settrace(save_trace)
# TestResults(failed=0, attempted=14)

# %%
#PCA and classification - Assignment 2


#1.  import libs and dataset
from sklearn.datasets import load_breast_cancer
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

breast_cancer = load_breast_cancer()

# print(breast_cancer.feature_names)
# print(len(breast_cancer.feature_names))
# print(breast_cancer.target) 
# print(breast_cancer.target_names) 
# print(np.array(np.unique(breast_cancer.target, return_counts=True)))


#2.  Load data into dataframe
#    https://pandas.pydata.org/docs/reference/frame.html 
breast_cancer_DF = pd.DataFrame(data=breast_cancer.data, columns=breast_cancer.feature_names)

breast_cancer_DF.head()

#3.  Train and test a model using all the features with Logistic regression
#    Use the unscaled (raw) dataset - we will scale and rerun in the next step.
#    Use a train/test split of 70/30 (30% test)
#    https://scikit-learn.org/stable/modules/classes.html#module-sklearn.model_selection
#    https://scikit-learn.org/stable/modules/classes.html#module-sklearn.linear_model     
#    https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression.fit 
#    https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression.score

#YOUR CODE HERE
#Assign indep and dep vars (X, y) from your dataframe 
#Generate training split (X_train, X_test, y_train, y_test)
#Perform Logistic Regresssion on your training data
#Generate the score of your model (e.g. _.score(X_test, y_test))
#print('Logistic regression model score on original UNSCALED dataset (all features):', _.score(X_test,y_test))
Y = pd.Series(breast_cancer.target)
X = breast_cancer_DF

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.20)

logic = LogisticRegression().fit(X_train, Y_train)
score = logic.score(X_test, Y_test)
print('Logistic regression model score on original UNSCALED dataset (all features):', score)

#4.  Scale data using Standard Scaling - this will be for PCA processing
#    Rerun logistic regression model on the scaled data to have apples to apples comparison on score after PCA.
#    https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler
#    https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler.fit_transform 
#
#YOUR CODE HERE
#Scale data with standard scaler
#Generate training split (X_train_scaled, X_test_scaled, y_train, y_test)
#Perform Logistic Regresssion on your training data (X_train_scaled, y_train)
#Generate the score of your model (e.g. _scaled.score(X_test_scaled, y_test))
#print('Logistic regression model score on original SCALED dataset (all features):', _scaled.score(X_test_scaled,y_test))
Y = pd.Series(breast_cancer.target)
StandardScaler()
X = StandardScaler().fit_transform(breast_cancer_DF, Y)

X_train_scaled, X_test_scaled, Y_train, Y_test = train_test_split(X, Y, test_size=.20)

logic_scaled = LogisticRegression().fit(X_train_scaled, Y_train)
score = logic_scaled.score(X_test_scaled, Y_test)
print('Logistic regression model score on original SCALED dataset (all features):', score)

#5. Perform PCA keeping all components (e.g. components=None)
#   Make sure to perform PCA using the scaled data
#   https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html#sklearn.decomposition.PCA 
#   https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html#sklearn.decomposition.PCA.fit
#YOUR CODE HERE
#use None to keep all components
pca = PCA().fit(X_train_scaled, Y_train)

#6. Generate the explained variances
#   Interpret the results
#   How much data variability does the 1st PC capture?
#   How much data variability does the 1st + 2nd PCs capture?
#   
#YOUR CODE HERE
#Generate explained variance ratio
#Generate cumulative variance ratios (_.cumsum())
#print("Variances (Percentage):")
#print(pca.explained_variance_ratio_ * 100)
#print("Cumulative Variances (Percentage):")
#print(pca.explained_variance_ratio_.cumsum() * 100)
print(f"""
Explained Variance Ratio: {pca.explained_variance_ratio_}
Cumulative Variance Ratios: {np.cumsum(pca.explained_variance_ratio_)}
Variances (Percentage): {pca.explained_variance_ratio_ * 100}
Cumulative Variances (Percentage): {np.cumsum(pca.explained_variance_ratio_) * 100}
""")

#7.  Generate Scree plot to view cumulative variances
#    https://seaborn.pydata.org/generated/seaborn.barplot.html
#    https://seaborn.pydata.org/generated/seaborn.lineplot.html 
#YOUR CODE HERE
print('\n \n')
plot = sns.lineplot(data=np.cumsum(pca.explained_variance_ratio_))
#8.  Apply PCA with explained variance percentage (70%, 80%, 90%)
#    or use retained number of components corresponding to these %s
#    (use None to keep all components)
#    You will need to rerun PCA with the n_components parameter set.
#    Print the pca components_ to observe the importance each feature contributes
#    to each of the principal components.
#    Identify the top 3 most important features in each component.
#YOUR CODE HERE
#pca = PCA(n_components = 0.70)
#pca = PCA(n_components = 0.80)
#pca = PCA(n_components = 0.90)
print(f"""
PCA with 70% of components: {PCA(n_components = 0.70).fit(X_train_scaled, Y_train).components_}
PCA with 80% of components: {PCA(n_components = 0.80).fit(X_train_scaled, Y_train).components_}
PCA with 90% of components: {PCA(n_components = 0.90).fit(X_train_scaled, Y_train).components_}
""")

#9.  Transform original features into k PCs
#    Use the scaled input data
#    https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html#sklearn.decomposition.PCA.transform 
#YOUR CODE HERE
X = pca.transform(X)

#10. Rerun Logistic regression with reduced feature set 
#    Use the transformed independent variables, and use the original y
#    Use the same train/test split as previous.
#    Generate training split (X_train_pca, X_test_pca, y_train, y_test)
#    Perform Logistic Regresssion using (X_train_scaled, y_train)
#    Generate score (e.g. _pca.score(X_test_pca, y_test))
#YOUR CODE HERE
#print('Logistic regression model score on transformed dataset:', _pca.score(X_test_pca,y_test))
Y = pd.Series(breast_cancer.target)

X_train_pca, X_test_pca, Y_train, Y_test = train_test_split(X, Y, test_size=.20)

logic_pca = LogisticRegression().fit(X_train_pca, Y_train)
score = logic_pca.score(X_test_pca, Y_test)
print('Logistic regression model score on trasnformed dataset (all features):', score)

for n in range(7, 10):
  pca = PCA(n_components = float(n/10)).fit(X_train_scaled, Y_train).transform(X)
  Y = pd.Series(breast_cancer.target)
  
  X_train_pca, X_test_pca, Y_train, Y_test = train_test_split(X, Y, test_size=.20)

  print(f"Logistic regression model score {str(n*10)}% of components: {LogisticRegression().fit(X_train_pca, Y_train).score(X_test_pca, Y_test)}")

#Evaluate and reflect on your results 
#   Logistic Regression model performance on original dataset - unscaled and scaled
#   Logistic Regression model performance after feature reduction 
#     using PCA to 70%, 80%, 90% cumulative explained variance ratio


# ******REFLECTION******
# Before running the feature reduction, I got a scores of 94.7(unscaled) and 97.3(scaled) for
# the data, but I knew I could do better. Once running the PCA dimension reduction I got 
# scores of 98.2%. 
# I think that this is due to logstic regression's ability to work well with binary output machine learning models.
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic regression model score on original UNSCALED dataset (all features): 0.9210526315789473
# Logistic regression model score on original SCALED dataset (all features): 0.9210526315789473
#
# Explained Variance Ratio: [4.42416350e-01 1.92998521e-01 9.32317345e-02 6.50085068e-02
#  5.74556267e-02 3.93470701e-02 2.24650208e-02 1.47645739e-02
#  1.36026318e-02 1.04657422e-02 9.91968591e-03 8.46417313e-03
#  8.10733882e-03 5.36127828e-03 3.27851041e-03 2.65909951e-03
#  1.95831930e-03 1.80219209e-03 1.47636481e-03 1.08329665e-03
#  9.40692312e-04 8.65901849e-04 7.23785523e-04 5.52806834e-04
#  5.12690790e-04 2.56616377e-04 1.99088542e-04 5.55754238e-05
#  2.25209717e-05 4.28468023e-06]
# Cumulative Variance Ratios: [0.44241635 0.63541487 0.72864661 0.79365511 0.85111074 0.89045781
#  0.91292283 0.9276874  0.94129004 0.95175578 0.96167546 0.97013964
#  0.97824698 0.98360825 0.98688676 0.98954586 0.99150418 0.99330638
#  0.99478274 0.99586604 0.99680673 0.99767263 0.99839642 0.99894922
#  0.99946191 0.99971853 0.99991762 0.99997319 0.99999572 1.        ]
# Variances (Percentage): [4.42416350e+01 1.92998521e+01 9.32317345e+00 6.50085068e+00
#  5.74556267e+00 3.93470701e+00 2.24650208e+00 1.47645739e+00
#  1.36026318e+00 1.04657422e+00 9.91968591e-01 8.46417313e-01
#  8.10733882e-01 5.36127828e-01 3.27851041e-01 2.65909951e-01
#  1.95831930e-01 1.80219209e-01 1.47636481e-01 1.08329665e-01
#  9.40692312e-02 8.65901849e-02 7.23785523e-02 5.52806834e-02
#  5.12690790e-02 2.56616377e-02 1.99088542e-02 5.55754238e-03
#  2.25209717e-03 4.28468023e-04]
# Cumulative Variances (Percentage): [ 44.24163503  63.54148709  72.86466055  79.36551123  85.11107389
#   89.0457809   91.29228299  92.76874037  94.12900355  95.17557778
#   96.16754637  97.01396368  97.82469756  98.36082539  98.68867643
#   98.95458638  99.15041831  99.33063752  99.478274    99.58660367
#   99.6806729   99.76726309  99.83964164  99.89492232  99.9461914
#   99.97185304  99.99176189  99.99731943  99.99957153 100.        ]
#
#
#
#
#
# PCA with 70% of components: [[ 0.2188447   0.11765246  0.22729467  0.22150883  0.13485173  0.23358722
#    0.25265322  0.25547876  0.14032664  0.06079369  0.2179217   0.04320184
#    0.22245252  0.21531405  0.02165502  0.17169206  0.15782395  0.18842339
#    0.05004732  0.10792452  0.22721781  0.11633659  0.23482229  0.22502908
#    0.11891934  0.19955124  0.22172091  0.24541539  0.11422311  0.12346874]
#  [-0.22794759 -0.07308127 -0.20911662 -0.2274349   0.18589545  0.15553002
#    0.06876746 -0.02669949  0.19432848  0.36192298 -0.10971895  0.09033657
#   -0.09276237 -0.16292235  0.19116717  0.23979714  0.22159219  0.15500715
#    0.17957854  0.29137838 -0.2189825  -0.05888475 -0.19818734 -0.22075851
#    0.15958514  0.13493001  0.09942035 -0.00164374  0.12968796  0.25458639]
#  [-0.00481617 -0.04884217 -0.00591727  0.03808277 -0.10260942 -0.07778362
#   -0.00532688 -0.03179026 -0.04174383 -0.01692431  0.27406322  0.28182989
#    0.27690409  0.24199565  0.26346571  0.15466254  0.18059341  0.21924927
#    0.2834821   0.22892375 -0.05126794 -0.15727751 -0.05274995 -0.01094562
#   -0.28135077 -0.2508413  -0.19469119 -0.1857302  -0.27843049 -0.24005183]]
# PCA with 80% of components: [[ 0.2188447   0.11765246  0.22729467  0.22150883  0.13485173  0.23358722
#    0.25265322  0.25547876  0.14032664  0.06079369  0.2179217   0.04320184
#    0.22245252  0.21531405  0.02165502  0.17169206  0.15782395  0.18842339
#    0.05004732  0.10792452  0.22721781  0.11633659  0.23482229  0.22502908
#    0.11891934  0.19955124  0.22172091  0.24541539  0.11422311  0.12346874]
#  [-0.22794759 -0.07308127 -0.20911662 -0.2274349   0.18589545  0.15553002
#    0.06876746 -0.02669949  0.19432848  0.36192298 -0.10971895  0.09033657
#   -0.09276237 -0.16292235  0.19116717  0.23979714  0.22159219  0.15500715
#    0.17957854  0.29137838 -0.2189825  -0.05888475 -0.19818734 -0.22075851
#    0.15958514  0.13493001  0.09942035 -0.00164374  0.12968796  0.25458639]
#  [-0.00481617 -0.04884217 -0.00591727  0.03808277 -0.10260942 -0.07778362
#   -0.00532688 -0.03179026 -0.04174383 -0.01692431  0.27406322  0.28182989
#    0.27690409  0.24199565  0.26346571  0.15466254  0.18059341  0.21924927
#    0.2834821   0.22892375 -0.05126794 -0.15727751 -0.05274995 -0.01094562
#   -0.28135077 -0.2508413  -0.19469119 -0.1857302  -0.27843049 -0.24005183]
#  [-0.04449686  0.59056734 -0.04469458 -0.05662657 -0.24386002 -0.04527081
#   -0.01265613 -0.08152091 -0.07922697 -0.06097761 -0.08237564  0.37382581
#   -0.06107256 -0.1049754  -0.05261167  0.09700386  0.07686799 -0.00920714
#    0.03459394  0.04798444 -0.02988085  0.5931635  -0.02293029 -0.03990977
#   -0.13695588  0.06121346  0.05504061 -0.04043874  0.01124174  0.02503501]
#  [ 0.0536288  -0.13705264  0.05193959  0.02648245 -0.3709127   0.01574372
#    0.09220053 -0.0353468  -0.26575789 -0.04613136 -0.1520925  -0.24634267
#   -0.12153228 -0.1288418  -0.30202959  0.25185748  0.3374958   0.15943453
#   -0.20382649  0.23796597  0.01538288 -0.17186568  0.0254846  -0.00839593
#   -0.34556603  0.12853515  0.19885581  0.06031704 -0.1734905   0.08696184]]
# PCA with 90% of components: [[ 0.2188447   0.11765246  0.22729467  0.22150883  0.13485173  0.23358722
#    0.25265322  0.25547876  0.14032664  0.06079369  0.2179217   0.04320184
#    0.22245252  0.21531405  0.02165502  0.17169206  0.15782395  0.18842339
#    0.05004732  0.10792452  0.22721781  0.11633659  0.23482229  0.22502908
#    0.11891934  0.19955124  0.22172091  0.24541539  0.11422311  0.12346874]
#  [-0.22794759 -0.07308127 -0.20911662 -0.2274349   0.18589545  0.15553002
#    0.06876746 -0.02669949  0.19432848  0.36192298 -0.10971895  0.09033657
#   -0.09276237 -0.16292235  0.19116717  0.23979714  0.22159219  0.15500715
#    0.17957854  0.29137838 -0.2189825  -0.05888475 -0.19818734 -0.22075851
#    0.15958514  0.13493001  0.09942035 -0.00164374  0.12968796  0.25458639]
#  [-0.00481617 -0.04884217 -0.00591727  0.03808277 -0.10260942 -0.07778362
#   -0.00532688 -0.03179026 -0.04174383 -0.01692431  0.27406322  0.28182989
#    0.27690409  0.24199565  0.26346571  0.15466254  0.18059341  0.21924927
#    0.2834821   0.22892375 -0.05126794 -0.15727751 -0.05274995 -0.01094562
#   -0.28135077 -0.2508413  -0.19469119 -0.1857302  -0.27843049 -0.24005183]
#  [-0.04449686  0.59056734 -0.04469458 -0.05662657 -0.24386002 -0.04527081
#   -0.01265613 -0.08152091 -0.07922697 -0.06097761 -0.08237564  0.37382581
#   -0.06107256 -0.1049754  -0.05261167  0.09700386  0.07686799 -0.00920714
#    0.03459394  0.04798444 -0.02988085  0.5931635  -0.02293029 -0.03990977
#   -0.13695588  0.06121346  0.05504061 -0.04043874  0.01124174  0.02503501]
#  [ 0.0536288  -0.13705264  0.05193959  0.02648245 -0.3709127   0.01574372
#    0.09220053 -0.0353468  -0.26575789 -0.04613136 -0.1520925  -0.24634267
#   -0.12153228 -0.1288418  -0.30202959  0.25185748  0.3374958   0.15943453
#   -0.20382649  0.23796597  0.01538288 -0.17186568  0.0254846  -0.00839593
#   -0.34556603  0.12853515  0.19885581  0.06031704 -0.1734905   0.08696184]
#  [ 0.03164845 -0.06959917  0.03064815  0.00886021 -0.21053473 -0.00567098
#   -0.02034106 -0.03424645  0.42594451 -0.13398324 -0.0286889  -0.06318495
#   -0.00401563 -0.04465543 -0.27421423  0.03235708  0.02106166 -0.0296114
#    0.48924908 -0.10478238  0.0030565  -0.08338253  0.01056915 -0.02481088
#   -0.31764366  0.02232428 -0.00114003 -0.03086931  0.53720532 -0.12022175]
#  [-0.13431766  0.06505907 -0.12502686 -0.05596945 -0.18662358  0.0121306
#   -0.11980696 -0.17370136 -0.08778805  0.28039072  0.29186355 -0.2399466
#    0.29454789  0.34924251 -0.15199699  0.0431966  -0.19659347 -0.37360965
#   -0.00979194  0.19356149 -0.0133449   0.04061798 -0.00430659  0.06798814
#   -0.07915689  0.14782034 -0.05396493 -0.16203786  0.07585696  0.36245664]]
#
# Logistic regression model score on trasnformed dataset (all features): 0.9824561403508771
# Logistic regression model score 70% of components: 0.9473684210526315
# Logistic regression model score 80% of components: 1.0
# Logistic regression model score 90% of components: 0.9649122807017544
